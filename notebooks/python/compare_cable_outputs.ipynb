# %%
import pandas as pd
import xarray as xr
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime, timedelta

# %%
run_output = xr.open_dataset('/Users/phelps/PhD/CABLE/runs/19-01-26/outputs/plume_out_cable_1901_2005.nc')
alison_output = xr.open_dataset('/Users/phelps/PhD/CABLE/a_bennett2023_code/site_level_simulations/Acclim_off/WombatStateForest/plume_out_cable_1901_2005.nc')

# %%
variable ='GPP'

data = pd.DataFrame(run_output[variable])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 variable ='GPP'
# ----> 3 data = pd.DataFrame(run_output[variable])
#
# File /opt/miniconda3/envs/phd_venv/lib/python3.12/site-packages/pandas/core/frame.py:871, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     863         mgr = arrays_to_mgr(
#     864             arrays,
#     865             columns,
#    (...)    868             typ=manager,
#     869         )
#     870     else:
# --> 871         mgr = ndarray_to_mgr(
#     872             data,
#     873             index,
#     874             columns,
#     875             dtype=dtype,
#     876             copy=copy,
#     877             typ=manager,
#     878         )
#     879 else:
#     880     mgr = dict_to_mgr(
#     881         {},
#     882         index,
#    (...)    885         typ=manager,
#     886     )
#
# ...

# %%
# Out:
# <xarray.DataArray 'GPP' (time: 1260, patch: 1, land: 1)> Size: 5kB
# [1260 values with dtype=float32]
# Coordinates:
#   * time     (time) object 10kB 1901-01-16 12:00:00 ... 2005-12-16 12:00:00
# Dimensions without coordinates: patch, land
# Attributes:
#     units:      umol/m^2/s
#     long_name:  Gross primary production
